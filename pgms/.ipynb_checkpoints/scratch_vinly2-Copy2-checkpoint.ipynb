# %% [markdown]
# ### Research Ideas:
# - Predict (collector) vinyl price
# - https://blog.discogs.com/en/discogs-top-100-most-expensive-records/
# - limits: only 100 data points
# - can we obtain # copies/presses
# - The goal isn't to analyze why recs have gone up in general, but if collector, what are some attributes that may predict the price. OR we can ask what are some attributes that predict the RATINGS of expensive recs
#
# **UPDATED**
# **DISCOGS**
# - most expensive lists: https://www.discogs.com/lists?list=expensive+items&page=2
# - use this to obtain all years (2010-2019)
# - example of month (jan2010): https://www.discogs.com/lists/Most-expensive-items-sold-in-Discogs-Marketplace-for-October-2010/140095
# - example of album within month (jan2010): https://www.discogs.com/La-Monte-Young-Drift-Study-43740-50950-PM-5-VIII-68-NYC/release/1512276
# - example of 100 expensive from archives: http://web.archive.org/web/20180502225137/https://blog.discogs.com/en/discogs-top-100-most-expensive-records/
# - graph of 10 years: https://blog.discogs.com/en/discogs-top-100-most-expensive-records/
#
# **MISC MUSIC**
# - vinylfactory: https://thevinylfactory.com/features/online-tools-for-record-collectors/
# - links to spotify: http://www.disconest.com/
# - discogs misc: https://web.archive.org/web/20210106081812/https://blog.discogs.com/en/
# - discogs misc: https://blog.discogs.com/en/vinyl-record-price-guide/
# - data: https://www.discogs.com/developers#page:user-collection
# - data: https://data.discogs.com/?prefix=data/2020/
# - pitchfork: https://pitchfork.com/reviews/best/reissues/?page=1
# - spotify github: https://github.com/nsgrantham/pitchfork-reviews
# - spotify kaggle: https://www.kaggle.com/yamaerenay/spotify-dataset-19212020-160k-tracks
# - spotify medium: https://towardsdatascience.com/step-by-step-to-visualize-music-genres-with-spotify-api-ce6c273fb827
# - discogs (full code): http://www.diva-portal.org/smash/get/diva2:1443317/FULLTEXT01.pdf
#
# **NEW LIST - ALL ITEMS. Need to pare down to something specific**
# **to consider:**
# - vintage vinyl years?
# - jazz only?
# - certain format?
# - create ranking of how many times an arist shows up in list
# - differential in haves and wants?
# - price history?
#
# - dicogs: lists: https://www.discogs.com/user/discogs/lists?header=1
# - https://medium.com/@kdavis7190/vinyl-resale-price-prediction-6cb0adaedcb9
# - https://github.com/kdavis01/projects/blob/master/vinyl_resale_regression/Data_Gathering.ipynb
#
# **For Write up:**
# - https://dgmono.com/2014/01/08/perspective-collecting-vintage-jazz-vinyl-a-labor-of-love/

# %% [markdown]
# ## I. setup

# %%
from bs4 import BeautifulSoup
import requests

## allows us to use reg expressions to search fields
import re
#runtime_regex = re.compile('Run')
#soup.find(text=runtime_regex)
import pandas as pd
from fake_useragent import UserAgent

# %% [markdown]
# ### Function 1: for PRICE only
# - this is different because it takes the first instance of the value in the field name
# - may need to create a separate function for cleaning this field (no $)

# %%
def get_album_price(soup, field_name):
    
    '''
    Grab a value from discogs archive HTML
    Takes a string attribute of an album on the page and returns the string
    We can go directly to the field name using the class element
    
    This will be used for:
        . have, wants, rating, numrating, price
    '''
    if soup.find_all(class_=field_name):
        obj = soup.find_all(class_=field_name)[0].text
    #print(obj)
        return obj
    else:
        obj=float('NaN')
        return obj
    
    #if not obj: 
    #    return None
    
    # this works for most of the values
#     next_element = obj.findNext()
#     print(next_element)
    
#     if next_element:
#         return next_element.text 

#     else:
#         return None

# %% [markdown]
# ### Function 2: for regular expression items
# - the majority of our variables will process through this

# %%
def get_album_txt(soup, field_name):
    
    '''Grab a value from discogs archive HTML
    
    Takes a string attribute of an album on the page and returns the string in
    the next sibling object (the value for that attribute) or None if nothing is found.
    '''
    
    obj = soup.find(text=re.compile(field_name))
    print(obj)
    if not obj: 
        return None
    
    # this works for most of the values
    next_element = obj.findNext()
    print(next_element)
    if next_element:
        return next_element.text 

    else:
        return None

# %% [markdown]
# #### Diagnostics below only work if soup is defined

# %%
# rated

rating = get_album_txt(soup,'Rated').strip()
#rated = get_album_txt(soup,'Rated').strip()
print(rating)

# %%
# ratings
gen = get_album_txt(soup,'Genre:').strip()
print(gen)

# %%
sleeve=soup.find(text=re.compile('Sleeve:..VG'))

#sleeve = get_album_txt(_soup,'Sleeve:').strip()
print(sleeve)

# %% [markdown]
# ### Function 3: Grab votes, have, want
# - performed parsing of votes field into haves/wants

# %%
def get_album_votes(soup, field_name, rtype ):
    
    '''Grab a value from discogs archive HTML
       Takes info in votes containing #votes, haves, wants
    '''    
    obj = soup.find(text=re.compile(field_name))
    #return obj

    if not obj:
        return None
    
    
#     if obj=='No Rating Yet':
#         return None
        
    splitvotes = obj.split('(')[0].strip()
    #print(splitvotes)
    #return splitvotes
    
    # parse votes
    if rtype == 'vote':
        votes = splitvotes.split(' ',1)[1].split(' ',1)[0]
        #print(votes)
        return votes

    # parse haves
    elif rtype=='have':
        splithaves = obj.split('(')[1].strip()
        #print(splithaves)
        #return splithaves
        haves= splithaves.split(',',1)[0].split(' ',1)[0]
        #print(haves)
        return haves
    
    # parse wants
    elif rtype=='want':
        splitwants = obj.split('(')[1].split(',',1)[1].strip()
        #print(splitwants)
        wants = splitwants.split(' ',1)[0]
        #print(wants)
        return wants
        
    else:
        return None

# %% [markdown]
# ### Function 4: Sleeve condition

# %%
def get_album_sleeve(soup, field_name):

    # Condition is a way to get to sleeve
    _sl  = soup.find(text=re.compile(field_name))
    _sl2 =_sl.findNext().find_all('p')[1].text
    sleeve=_sl2.split(' ',0)[0].split(':',1)[1].strip()
    #print(sleeve)
    return sleeve

# %% [markdown]
# #### Diagnostic works only if soup is defined

# %%
# string of have/wants, etc. they need to be parsed
votestr = get_album_votes(_soup,'votes','want')
print(votestr)

# %% [markdown]
# #### Create helper functions to parse strings into appropriate data types_
# - The returned values all need a bit of formatting before we can work with this data.  Here are a few helper functions.

# %%
import dateutil.parser

def money_to_int(moneystring):
    moneystring = moneystring.replace('$', '').replace(',', '')
    return int(float(moneystring))

def to_date(datestring):
    date = dateutil.parser.parse(datestring)
    return date

# %% [markdown]
# ## RANDOM TIMER (if necessary)

# %%
import random
import time

# append the page number

# %%
#

# %% [markdown]
# ### II. STARTING POINT
# - enter url of page with list depending on filters

# %%
# Jazz bop only
url='https://www.discogs.com/sell/list?sort=price%2Cdesc&limit=100&year1=1900&year2=1970&format=Vinyl&price=over40&genre=Jazz&currency=USD&style=Hard+Bop&page=1'
response=requests.get(url)
response.status_code
# Out:
# 200

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print(soup.prettify())

# %% [markdown]
# #### obtain all rows of data, eventually parsing out links per album

# %%
rows = [row for row in soup.find(class_='table_block mpitems push_down table_responsive')
        .find_all('tr',class_='shortcut_navigable')]  # tr tag is for rows

# %%
# We are only looking for the LINK. and inside the link we'll pull data
rows

# %% [markdown]
# ### Full code to scrape each page and link
# - Extract list of links for each album/row of data
# - gives specific links to album pages

# %%
# Jazz bop only
# This is where you can also set your timers

from fake_useragent import UserAgent

n=2
#def discogsall():
#page_list = ['2']
page_list = [str(i) for i in str(n)]

r = "https://www.discogs.com/sell/list?sort=price%2Cdesc&limit=100&year1=1900&year2=1970&format=Vinyl&price=over40&genre=Jazz&currency=USD&style=Hard+Bop&page="

# initialize final album list
coveralbinfo = [] # albumlist
inneralbinfo = [] # alb_page_info_list
    
for page in range(1,3): #page_list:
        
    url= r + str(page) + "#more%3Dyear" 
    
    ua = UserAgent()
    user_agent = {'User-agent': ua.random}
    #response  = requests.get(url, headers = user_agent)    

    response=requests.get(url,headers=user_agent)
    spage = response.text
    soup = BeautifulSoup(spage, "lxml")

    #time.sleep(.5+2*random.random())

    rows = [row for row in soup.find(class_='table_block mpitems push_down table_responsive')
            .find_all('tr',class_='shortcut_navigable')]  # tr tag is for rows
    
    '''
    ----------------------------------------------------------
    2. Call function for grabbing data from each row
    ----------------------------------------------------------    
    '''
    albumlist = {}

    for row in rows[0:]:

        '''
        items are the number of items within a td block (columns).
        there are 6 items in a block
        '''
        items = row.find_all('td')
        #print(len(items))
        #print(items)

        #link = row.find('a')['href']    
        # just take the first item in the td block whihch is link
        link = items[1].find('a')['href']
        #print(link)

        # for title, take the full artist+title for uniqueness. otherwise, dictionary will get unique artist only
        _link = items[1].find('a')

        #arttitle= _link.text #.split('-')[0].strip()

        artist= _link.text.split('-')[0].strip()

        #title1 = title_string.split('-')[1].strip()

        title1 = _link.text.split('-')[1].strip()
        title  = title1.split('(')[0].strip()

        arttitle=artist+" - "+title
        #print("art+title",arttitle,"art",artist)

        # sleeve
        if items[1].find('span',class_="item_sleeve_condition"):
            sleeve=items[1].find('span',class_="item_sleeve_condition").text.strip()
            #print(sleeve)
        else:
            sleeve=''
        
        albumlist[arttitle] = [link] + [artist] + [title] + [sleeve]
        #print(albumlist)
        #albumlist[title] = [link] + [i.text for i in items]
    
        ## END FOR LOOP (COVER)
    
    #print(albumlist)
    alb = pd.DataFrame(albumlist).T
    alb.columns = ['link_stub','artist','title','sleeve']
    coveralbinfo.append(albumlist)
    '''
    ----------------------------------------------------------
    3. Call function for grabbing data from each album
    ----------------------------------------------------------
    '''

    # LINK_STUB is the added parts to the URL
    alb_page_info_list = []

    for link in alb.link_stub:
        alb_page_info_list.append(get_album_dict(link))

        # This is your end product of info per page. you want this to be unique and set aside so it's appended to the next pages    
        #print(alb_page_info_list)
        
    #final_album_list.append(alb_page_info_list)
    
    
inneralbinfo.append(alb_page_info_list)
#coveralbinfo.append(albumlist)

print("Page Number:",page)

time.sleep(2+2*random.random())

        # convert dictionary to DF
    #     alb_page_info[page] = pd.DataFrame(alb_page_info_list)  #convert list of dict to df
    #     alb_page_info[page].set_index('arttitle', inplace=True)
    #     alb_page_info[page]
# Out:
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4041
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4041
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1960
#
#                 </div>
# Released:
# <div class="content">
#                                             1960
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.58</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1549
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1549
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             May 1957
#
#                 </div>
# Released:
# <div class="content">
#                                             May 1957
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.76</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BST 84115
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BST 84115
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Stereo
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Stereo
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1962
#
#                 </div>
# Released:
# <div class="content">
#                                             1962
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.92</span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1567
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1567
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1957
#
#                 </div>
# Released:
# <div class="content">
#                                             1957
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.50</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4169
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4169
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1966
#
#                 </div>
# Released:
# <div class="content">
#                                             1966
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.54</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1595,
#             <a href="/label/281-Blue-Note">Blue Note</a> ‎– 1595
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1595,
#             <a href="/label/281-Blue-Note">Blue Note</a> ‎– 1595
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             May 1958
#
#                 </div>
# Released:
# <div class="content">
#                                             May 1958
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Bop, Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Bop, Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.70</span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1540
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1540
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1957
#
#                 </div>
# Released:
# <div class="content">
#                                             1957
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.57</span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– PRESTIGE 3
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– PRESTIGE 3
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, 16 ⅔ RPM, Compilation
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, 16 ⅔ RPM, Compilation
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1957
#
#                 </div>
# Released:
# <div class="content">
#                                             1957
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Cool Jazz, Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Cool Jazz, Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.50</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/639322-Jazz-Line-2">Jazz Line (2)</a> ‎– JAZ-33-01
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/639322-Jazz-Line-2">Jazz Line (2)</a> ‎– JAZ-33-01
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.67</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/43116-Pacific-Jazz">Pacific Jazz</a> ‎– PJ-81
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/43116-Pacific-Jazz">Pacific Jazz</a> ‎– PJ-81
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1963
#
#                 </div>
# Released:
# <div class="content">
#                                             1963
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz, Funk / Soul
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz, Funk / Soul
#
#             </div>
# Style:
# <div class="content">
#
#         Soul-Jazz, Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Soul-Jazz, Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.00</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4140
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4140
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1963
#
#                 </div>
# Released:
# <div class="content">
#                                             1963
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.61</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/26557-Impulse!">Impulse!</a> ‎– AS-77
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/26557-Impulse!">Impulse!</a> ‎– AS-77
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Stereo, <i>Gatefold</i>
# <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Stereo, <i>Gatefold</i>
# <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1965
#
#                 </div>
# Released:
# <div class="content">
#                                             1965
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Free Jazz, Hard Bop, Modal
#
#             </div>
# Style:
# <div class="content">
#
#         Free Jazz, Hard Bop, Modal
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.67</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4163
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4163
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, Album, Mono, LP
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, Album, Mono, LP
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             Aug 1964
#
#                 </div>
# Released:
# <div class="content">
#                                             Aug 1964
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop, Free Jazz, Modal, Post Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop, Free Jazz, Modal, Post Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.82</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– LP 7058
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– LP 7058
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Repress, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Repress, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1958
#
#                 </div>
# Released:
# <div class="content">
#                                             1958
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Bop, Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Bop, Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.25</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– PRLP 7061
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– PRLP 7061
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1956
#
#                 </div>
# Released:
# <div class="content">
#                                             1956
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.50</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4045
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4045
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.33</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1544
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1544
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             Mar 1957
#
#                 </div>
# Released:
# <div class="content">
#                                             Mar 1957
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.26</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1574
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1574
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             Nov 1959
#
#                 </div>
# Released:
# <div class="content">
#                                             Nov 1959
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.50</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BST 84245
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BST 84245
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Reissue, Stereo
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Reissue, Stereo
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1967
#
#                 </div>
# Released:
# <div class="content">
#                                             1967
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">5.00</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/26409-Transition">Transition</a> ‎– TRLP 5
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/26409-Transition">Transition</a> ‎– TRLP 5
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1956
#
#                 </div>
# Released:
# <div class="content">
#                                             1956
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.45</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4017
#
#                 </div>
# Label:
# ...
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/149875-Tempo-Records-5">Tempo Records (5)</a> ‎– TAP 15
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/149875-Tempo-Records-5">Tempo Records (5)</a> ‎– TAP 15
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             UK
#
#                 </div>
# Country:
# <div class="content">
#                                             UK
#
#                 </div>
# Released:
# <div class="content">
#                                             1958
#
#                 </div>
# Released:
# <div class="content">
#                                             1958
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.33</span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4080
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 4080
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.53</span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good (VG)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good (VG)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/14624-Brunswick">Brunswick</a> ‎– 87 912
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/14624-Brunswick">Brunswick</a> ‎– 87 912
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             Germany
#
#                 </div>
# Country:
# <div class="content">
#                                             Germany
#
#                 </div>
# Released:
# <div class="content">
#                                             1963
#
#                 </div>
# Released:
# <div class="content">
#                                             1963
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop, Modal
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop, Modal
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.70</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/33726-Savoy-Records">Savoy Records</a> ‎– ST-13008,
#             <a href="/label/33726-Savoy-Records">Savoy Records</a> ‎– SST-13008
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/33726-Savoy-Records">Savoy Records</a> ‎– ST-13008,
#             <a href="/label/33726-Savoy-Records">Savoy Records</a> ‎– SST-13008
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Stereo
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Stereo
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1959
#
#                 </div>
# Released:
# <div class="content">
#                                             1959
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop, Modal
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop, Modal
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">5.00</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1521
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/281-Blue-Note">Blue Note</a> ‎– BLP 1521
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Compilation, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Compilation, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             Jul 1956
#
#                 </div>
# Released:
# <div class="content">
#                                             Jul 1956
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.60</span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Very Good Plus (VG+)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Very Good Plus (VG+)" data-format="Vinyl"></i>
# </span>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– 7200,
#             <a href="/label/19591-Prestige">Prestige</a> ‎– PRLP 7200
#
#                 </div>
# Label:
# <div class="content">
# <a href="/label/19591-Prestige">Prestige</a> ‎– 7200,
#             <a href="/label/19591-Prestige">Prestige</a> ‎– PRLP 7200
#
#                 </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Format:
# <div class="content">
#
#
#             Vinyl, LP, Album, Mono
#             <br/>
# </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Country:
# <div class="content">
#                                             US
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Released:
# <div class="content">
#                                             1961
#
#                 </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Genre:
# <div class="content">
#
#         Jazz
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
# Style:
# <div class="content">
#
#         Hard Bop
#
#             </div>
#
#                     Rated
# <span class="rating_value_sm">4.57</span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# Media:
# <span>
#         Near Mint (NM or M-)
#
#                     <i class="icon icon-info-circle muted media-condition-tooltip" data-condition="Near Mint (NM or M-)" data-format="Vinyl"></i>
# </span>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# Page Number: 2

# %%
coveralbinfo
# Out:
# [{'The John Coltrane Quartet - Africa / Brass': ['/sell/item/607395159',
#    'The John Coltrane Quartet',
#    'Africa / Brass',
#    'Near Mint (NM or M-)'],
#   'Thad Jones - Frank Wess': ['/sell/item/1211869208',
#    'Thad Jones',
#    'Frank Wess',
#    'Very Good Plus (VG+)'],
#   'Kenny Drew Quintet / Quartet* - This Is New': ['/sell/item/1165902763',
#    'Kenny Drew Quintet / Quartet*',
#    'This Is New',
#    'Very Good Plus (VG+)'],
#   'Donald Byrd - Byrd In Paris': ['/sell/item/1125083466',
#    'Donald Byrd',
#    'Byrd In Paris',
#    'Very Good (VG)'],
#   'Benny Carter Featuring The Voices Of Sammy Davis, Jr.*, Louis Armstrong And Mel Tormé - A Man Called Adam': ['/sell/item/934827549',
#    'Benny Carter Featuring The Voices Of Sammy Davis, Jr.*, Louis Armstrong And Mel Tormé',
#    'A Man Called Adam',
#    'Very Good Plus (VG+)'],
#   'Sonny Rollins - A Night At The "Village Vanguard"': ['/sell/item/1192843504',
#    'Sonny Rollins',
#    'A Night At The "Village Vanguard"',
#    'Near Mint (NM or M-)'],
#   'Stanley Turrentine - Up At "Minton\'s", Vol. 2': ['/sell/item/1279917909',
#    'Stanley Turrentine',
#    'Up At "Minton\'s", Vol. 2',
#    'Very Good Plus (VG+)'],
#   'Herbie Nichols - The Prophetic Herbie Nichols Vol. 2': ['/sell/item/993944474',
#    'Herbie Nichols',
#    'The Prophetic Herbie Nichols Vol. 2',
#    'Very Good (VG)'],
#   'Thelonious Monk - Brilliant Corners': ['/sell/item/1208828390',
#    'Thelonious Monk',
#    'Brilliant Corners',
#    'Very Good Plus (VG+)'],
#   'Herbie Hancock - Inventions And Dimensions': ['/sell/item/1189266612',
#    'Herbie Hancock',
#    'Inventions And Dimensions',
#    'Very Good Plus (VG+)'],
#   'Charles Mingus - Mingus Ah Um': ['/sell/item/1212396075',
#    'Charles Mingus',
#    'Mingus Ah Um',
#    'Very Good Plus (VG+)'],
#   'Jackie McLean - A Long Drink Of The Blues': ['/sell/item/1280369151',
#    'Jackie McLean',
#    'A Long Drink Of The Blues',
#    'Very Good Plus (VG+)'],
#   'Dexter Gordon - Dexter Calling . . .': ['/sell/item/1269889236',
#    'Dexter Gordon',
#    'Dexter Calling . . .',
#    'Very Good Plus (VG+)'],
#   'Dexter Gordon - Go!': ['/sell/item/894691708',
#    'Dexter Gordon',
#    'Go!',
#    'Very Good Plus (VG+)'],
#   "Bennie Green - Soul Stirrin'": ['/sell/item/1060581878',
#    'Bennie Green',
#    "Soul Stirrin'",
#    'Very Good Plus (VG+)'],
#   'Miles Davis - Blue Moods': ['/sell/item/954359814',
#    'Miles Davis',
#    'Blue Moods',
#    'Good Plus (G+)'],
#   'Eric Dolphy - Out To Lunch!': ['/sell/item/1202733530',
#    'Eric Dolphy',
#    'Out To Lunch!',
#    'Very Good Plus (VG+)'],
#   'John Coltrane With The Red Garland Trio - Traneing In': ['/sell/item/862620627',
#    'John Coltrane With The Red Garland Trio',
#    'Traneing In',
#    'Very Good Plus (VG+)'],
#   'John Coltrane - My Favorite Things': ['/sell/item/1143617682',
#    'John Coltrane',
#    'My Favorite Things',
#    'Very Good (VG)'],
#   'Ike Quebec - It Might As Well Be Spring': ['/sell/item/1071970629',
#    'Ike Quebec',
#    'It Might As Well Be Spring',
#    'Very Good (VG)'],
#   'Clifford Brown - Memorial Album': ['/sell/item/1038105415',
#    'Clifford Brown',
#    'Memorial Album',
#    'Very Good (VG)'],
#   'Benny Golson - Gone With Golson': ['/sell/item/786304712',
#    'Benny Golson',
#    'Gone With Golson',
#    'Very Good Plus (VG+)'],
#   'Booker Ervin With Dexter Gordon - Setting The Pace': ['/sell/item/979002648',
#    'Booker Ervin With Dexter Gordon',
#    'Setting The Pace',
#    'Mint (M)'],
#   'Wes Montgomery - The Incredible Jazz Guitar Of Wes Montgomery': ['/sell/item/1212658768',
#    'Wes Montgomery',
#    'The Incredible Jazz Guitar Of Wes Montgomery',
#    'Very Good Plus (VG+)'],
#   "Hank Mobley Quintet* - Mobley's 2nd Message": ['/sell/item/1279919559',
#    'Hank Mobley Quintet*',
#    "Mobley's 2nd Message",
#    'Very Good (VG)'],
#   "Bennie Green - Walkin' And Talkin'": ['/sell/item/1212547788',
#    'Bennie Green',
#    "Walkin' And Talkin'",
#    'Near Mint (NM or M-)'],
#   "Cannonball Adderley - Somethin' Else": ['/sell/item/1128219015',
#    'Cannonball Adderley',
#    "Somethin' Else",
#    'Very Good Plus (VG+)'],
#   'Jackie McLean - Destination... Out!': ['/sell/item/1207783232',
#    'Jackie McLean',
#    'Destination... Out!',
#    'Very Good Plus (VG+)'],
#   'Art Blakey & The Jazz Messengers - A Night In Tunisia': ['/sell/item/680104723',
#    'Art Blakey & The Jazz Messengers',
#    'A Night In Tunisia',
#    'Near Mint (NM or M-)'],
#   'Horace Silver Quintet* - Horace Silver Quintet Volume 3': ['/sell/item/1088240623',
#    'Horace Silver Quintet*',
#    'Horace Silver Quintet Volume 3',
#    'Very Good Plus (VG+)'],
#   "Jackie McLean - Makin' The Changes": ['/sell/item/1259748315',
#    'Jackie McLean',
#    "Makin' The Changes",
#    'Very Good Plus (VG+)'],
#   'Jackie McLean - Let Freedom Ring': ['/sell/item/727901084',
#    'Jackie McLean',
#    'Let Freedom Ring',
#    'Very Good Plus (VG+)'],
#   'Wayne Shorter - Juju': ['/sell/item/1280119398',
#    'Wayne Shorter',
#    'Juju',
#    'Very Good (VG)'],
#   'Woods* / Byrd* - The Young Bloods': ['/sell/item/1265215236',
#    'Woods* / Byrd*',
#    'The Young Bloods',
#    'Very Good (VG)'],
#   'The Jazz Messengers* - At The Cafe Bohemia Volume 2': ['/sell/item/1122724402',
#    'The Jazz Messengers*',
#    'At The Cafe Bohemia Volume 2',
#    'Very Good (VG)'],
#   'Dizzy Reece - Star Bright': ['/sell/item/993975349',
#    'Dizzy Reece',
#    'Star Bright',
#    'Very Good (VG)'],
#   'Horace Parlan Quintet - On The Spur Of The Moment': ['/sell/item/1023752955',
#    'Horace Parlan Quintet',
#    'On The Spur Of The Moment',
#    'Very Good Plus (VG+)'],
#   'Ike Quebec - Heavy Soul': ['/sell/item/1149660730',
#    'Ike Quebec',
#    'Heavy Soul',
#    'Very Good Plus (VG+)'],
#   'John Coltrane - Blue Train': ['/sell/item/1215808890',
#    'John Coltrane',
#    'Blue Train',
#    'Very Good (VG)'],
#   'Thad Jones, Billy Mitchell, Al Grey, Tommy Flanagan, Paul Chambers (3), Elvin Jones - Motor City Scene': ['/sell/item/1008485269',
#    'Thad Jones, Billy Mitchell, Al Grey, Tommy Flanagan, Paul Chambers (3), Elvin Jones',
#    'Motor City Scene',
#    'Very Good (VG)'],
#   'Hal Stein & Warren Fitzgerald (2) - Hal Stein & Warren Fitzgerald': ['/sell/item/853235558',
#    'Hal Stein & Warren Fitzgerald (2)',
#    'Hal Stein & Warren Fitzgerald',
#    'Very Good (VG)'],
#   'Hank Mobley - No Room For Squares': ['/sell/item/1203205350',
#    'Hank Mobley',
#    'No Room For Squares',
#    'Very Good Plus (VG+)'],
#   "Jackie McLean - Jackie's Bag": ['/sell/item/786273350',
#    'Jackie McLean',
#    "Jackie's Bag",
#    'Very Good Plus (VG+)'],
#   'Hank Mobley - The Turnaround': ['/sell/item/786229682',
#    'Hank Mobley',
#    'The Turnaround',
#    'Very Good (VG)'],
#   'Tommy Flanagan, John Coltrane, Kenny Burrell, Idrees Sulieman - The Cats': ['/sell/item/1022325374',
#    'Tommy Flanagan, John Coltrane, Kenny Burrell, Idrees Sulieman',
#    'The Cats',
#    'Very Good Plus (VG+)'],
#   'Sonny Rollins - Plus 4': ['/sell/item/1033672513',
#    'Sonny Rollins',
#    'Plus 4',
#    'Very Good (VG)'],
#   'Miles Davis Sextet* - Someday My Prince Will Come': ['/sell/item/496482760',
#    'Miles Davis Sextet*',
#    'Someday My Prince Will Come',
#    'Near Mint (NM or M-)'],
#   'Tubby Hayes And The Jazz Couriers Featuring Ronnie Scott - The Jazz Couriers': ['/sell/item/628395520',
#    'Tubby Hayes And The Jazz Couriers Featuring Ronnie Scott',
#    'The Jazz Couriers',
#    'Very Good (VG)'],
#   'Hank Mobley - Workout': ['/sell/item/1021660587',
#    'Hank Mobley',
#    'Workout',
#    'Very Good Plus (VG+)'],
#   'Michael Naura Quintet* - European Jazz Sounds': ['/sell/item/1149123138',
#    'Michael Naura Quintet*',
#    'European Jazz Sounds',
#    'Very Good (VG)'],
#   'Yusef Lateef And His Jazz Quintet* - The Fabric Of Jazz': ['/sell/item/542231823',
#    'Yusef Lateef And His Jazz Quintet*',
#    'The Fabric Of Jazz',
#    'Very Good Plus (VG+)'],
#   'Art Blakey Quintet - A Night At Birdland, Volume 1': ['/sell/item/1068076297',
#    'Art Blakey Quintet',
#    'A Night At Birdland, Volume 1',
#    'Very Good Plus (VG+)'],
#   "The Miles Davis Quintet - Steamin' With The Miles Davis Quintet": ['/sell/item/1278449952',
#    'The Miles Davis Quintet',
#    "Steamin' With The Miles Davis Quintet",
#    'Near Mint (NM or M-)'],
#   'John Coltrane - Lush Life': ['/sell/item/678616561',
#    'John Coltrane',
#    'Lush Life',
#    'Very Good Plus (VG+)'],
#   'Donald Byrd - Fuego': ['/sell/item/985715724',
#    'Donald Byrd',
#    'Fuego',
#    'Very Good Plus (VG+)'],
#   'Donald Byrd - Byrd In Flight': ['/sell/item/1264945524',
#    'Donald Byrd',
#    'Byrd In Flight',
#    'Very Good (VG)'],
#   'Jackie McLean - New Soil': ['/sell/item/1130302860',
#    'Jackie McLean',
#    'New Soil',
#    'Very Good Plus (VG+)'],
#   'Gigi Gryce Featuring Richard Williams - The Rat Race Blues': ['/sell/item/1121588080',
#    'Gigi Gryce Featuring Richard Williams',
#    'The Rat Race Blues',
#    'Very Good Plus (VG+)'],
#   'Sonny Clark Trio - Sonny Clark Trio': ['/sell/item/590151315',
#    'Sonny Clark Trio',
#    'Sonny Clark Trio',
#    'Very Good (VG)'],
#   'Sonny Rollins - Tour De Force': ['/sell/item/1122700600',
#    'Sonny Rollins',
#    'Tour De Force',
#    'Very Good Plus (VG+)'],
#   'The Dick Morrissey Quartet - Here And Now And Sounding Good!': ['/sell/item/542150069',
#    'The Dick Morrissey Quartet',
#    'Here And Now And Sounding Good!',
#    'Very Good (VG)'],
#   "Dexter Gordon - A Swingin' Affair": ['/sell/item/1033550696',
#    'Dexter Gordon',
#    "A Swingin' Affair",
#    'Near Mint (NM or M-)'],
#   'Miles Davis - Jazz Track': ['/sell/item/155558267',
#    'Miles Davis',
#    'Jazz Track',
#    'Very Good (VG)'],
#   "Hank Mobley - Mobley's Message": ['/sell/item/1221655941',
#    'Hank Mobley',
#    "Mobley's Message",
#    'Very Good Plus (VG+)'],
#   'Sonny Rollins - Way Out West': ['/sell/item/1185898023',
#    'Sonny Rollins',
#    'Way Out West',
#    'Very Good Plus (VG+)'],
#   'Nat Adderley - Work Song': ['/sell/item/1046536321',
#    'Nat Adderley',
#    'Work Song',
#    'Mint (M)'],
#   'Chet Baker - Chet': ['/sell/item/1112821363',
#    'Chet Baker',
#    'Chet',
#    'Very Good Plus (VG+)'],
#   'George Braith - Soul Stream': ['/sell/item/1008160036',
#    'George Braith',
#    'Soul Stream',
#    'Very Good Plus (VG+)'],
#   "The Horace Silver Quintet - Finger Poppin' With The Horace Silver Quintet": ['/sell/item/917427395',
#    'The Horace Silver Quintet',
#    "Finger Poppin' With The Horace Silver Quintet",
#    'Very Good Plus (VG+)'],
#   'Sonny Rollins - Sonny Rollins Volume 1': ['/sell/item/1171645286',
#    'Sonny Rollins',
#    'Sonny Rollins Volume 1',
#    'Very Good Plus (VG+)'],
#   "Sonny Rollins - Newk's Time": ['/sell/item/1175520741',
#    'Sonny Rollins',
#    "Newk's Time",
#    'Good Plus (G+)'],
#   'Wayne Shorter - Introducing Wayne Shorter': ['/sell/item/592934771',
#    'Wayne Shorter',
#    'Introducing Wayne Shorter',
#    'Near Mint (NM or M-)'],
#   'Eric Dolphy - Out There': ['/sell/item/892556940',
#    'Eric Dolphy',
#    'Out There',
#    'Very Good (VG)'],
#   "Miles Davis All Stars - Walkin'": ['/sell/item/1163506260',
#    'Miles Davis All Stars',
#    "Walkin'",
#    'Very Good Plus (VG+)'],
#   'Johnny Griffin - The Little Giant': ['/sell/item/1144500097',
#    'Johnny Griffin',
#    'The Little Giant',
#    'Very Good Plus (VG+)'],
#   'Dexter Gordon - Our Man In Paris': ['/sell/item/506994584',
#    'Dexter Gordon',
#    'Our Man In Paris',
#    'Very Good Plus (VG+)'],
#   "Jackie McLean - It's Time!": ['/sell/item/786228251',
#    'Jackie McLean',
#    "It's Time!",
#    'Very Good Plus (VG+)'],
#   'John Coltrane - A Love Supreme': ['/sell/item/1085113945',
#    'John Coltrane',
#    'A Love Supreme',
#    'Very Good Plus (VG+)'],
#   'Dizzy Reece - Asia Minor': ['/sell/item/1259426523',
#    'Dizzy Reece',
#    'Asia Minor',
#    'Very Good (VG)'],
#   'Lee Morgan - Search For The New Land': ['/sell/item/1261076169',
#    'Lee Morgan',
#    'Search For The New Land',
#    'Very Good Plus (VG+)'],
#   'Nick Ayoub Quintet - The Montreal Scene': ['/sell/item/1092072857',
#    'Nick Ayoub Quintet',
#    'The Montreal Scene',
#    'Near Mint (NM or M-)'],
#   'Donald Byrd - Off To The Races': ['/sell/item/1080808714',
#    'Donald Byrd',
#    'Off To The Races',
#    'Very Good Plus (VG+)'],
#   'Hank Mobley - Roll Call': ['/sell/item/904192172',
#    'Hank Mobley',
#    'Roll Call',
#    'Very Good Plus (VG+)'],
#   'Sonny Rollins - Freedom Suite': ['/sell/item/592927663',
#    'Sonny Rollins',
#    'Freedom Suite',
#    'Near Mint (NM or M-)']}]

# %%
#inneralbinfo[0][:1:-1]
inneralbinfo
# Out:
# [[{'arttitle': 'The John Coltrane Quartet - Africa / Brass',
#    'rlabel': 'Impulse!',
#    'rformat': 'Vinyl, LP, Album, Mono, Gatefold',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 9, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Free Jazz, Hard Bop, Modal',
#    'rating': 4.64,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 42,
#    'haves': 428,
#    'wants': 361},
#   {'arttitle': 'Thad Jones - Frank Wess',
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1957, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.5,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$587.99',
#    'votes': 14,
#    'haves': 58,
#    'wants': 236},
#   {'arttitle': 'Kenny Drew Quintet / Quartet* - This Is New',
#    'rlabel': 'Riverside Records',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1957, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.0,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$577.99',
#    'votes': 8,
#    'haves': 47,
#    'wants': 178},
#   {'arttitle': 'Donald Byrd - Byrd In Paris',
#    'rlabel': 'Signature (4)',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1960, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 5.0,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$571.62',
#    'votes': 1,
#    'haves': 7,
#    'wants': 92},
#   {'arttitle': 'Benny Carter Featuring The Voices Of Sammy Davis, Jr.*, Louis Armstrong And Mel Tormé - A Man Called Adam',
#    'rlabel': 'Reprise Records',
#    'rformat': 'Vinyl, LP, Album, Mono, Promo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1966, 1, 15, 0, 0),
#    'genre': 'Jazz, Blues',
#    'style': 'Hard Bop, Easy Listening, Dixieland, Swing, Cool Jazz',
#    'rating': 4.0,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$559.00',
#    'votes': 2,
#    'haves': 14,
#    'wants': 12},
#   {'arttitle': 'Sonny Rollins - A Night At The "Village Vanguard"',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1957, 12, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Bop',
#    'rating': 4.61,
#    'media': 'Very Good (VG)',
#    'price': '$400.00',
#    'votes': 44,
#    'haves': 295,
#    'wants': 496},
#   {'arttitle': 'Stanley Turrentine - Up At "Minton\'s", Vol. 2',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.55,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$400.00',
#    'votes': 11,
#    'haves': 89,
#    'wants': 167},
#   {'arttitle': 'Herbie Nichols - The Prophetic Herbie Nichols Vol. 2',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, 10", Album, Mono',
#    'country': 'USA & Canada',
#    'release_dt': datetime.datetime(1955, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.8,
#    'media': 'Good Plus (G+)',
#    'price': '$550.00',
#    'votes': 5,
#    'haves': 23,
#    'wants': 131},
#   {'arttitle': 'Thelonious Monk - Brilliant Corners',
#    'rlabel': 'Riverside Records',
#    'rformat': 'Vinyl, LP, Album, Mono, Deep Groove',
#    'country': 'US',
#    'release_dt': datetime.datetime(1957, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.38,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$550.00',
#    'votes': 56,
#    'haves': 381,
#    'wants': 1061},
#   {'arttitle': 'Herbie Hancock - Inventions And Dimensions',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1964, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Free Improvisation, Hard Bop, Modal',
#    'rating': 4.52,
#    'media': 'Very Good (VG)',
#    'price': '$475.00',
#    'votes': 42,
#    'haves': 169,
#    'wants': 829},
#   {'arttitle': 'Charles Mingus - Mingus Ah Um',
#    'rlabel': 'Columbia',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Bop',
#    'rating': 4.38,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$499.99',
#    'votes': 16,
#    'haves': 82,
#    'wants': 467},
#   {'arttitle': 'Jackie McLean - A Long Drink Of The Blues',
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.4,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$529.00',
#    'votes': 15,
#    'haves': 67,
#    'wants': 175},
#   {'arttitle': 'Dexter Gordon - Dexter Calling . . .',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, Album, LP, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 12, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.59,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$400.00',
#    'votes': 27,
#    'haves': 156,
#    'wants': 329},
#   {'arttitle': 'Dexter Gordon - Go!',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1962, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.67,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$525.00',
#    'votes': 52,
#    'haves': 310,
#    'wants': 741},
#   {'arttitle': "Bennie Green - Soul Stirrin'",
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1958, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.72,
#    'media': 'Mint (M)',
#    'price': '$513.69',
#    'votes': 18,
#    'haves': 144,
#    'wants': 258},
#   {'arttitle': 'Miles Davis - Blue Moods',
#    'rlabel': 'Debut Records',
#    'rformat': 'Vinyl, LP, Album',
#    'country': 'US',
#    'release_dt': datetime.datetime(1955, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.24,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$505.62',
#    'votes': 25,
#    'haves': 147,
#    'wants': 573},
#   {'arttitle': 'Eric Dolphy - Out To Lunch!',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1964, 8, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Free Jazz, Modal, Post Bop',
#    'rating': 4.62,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$502.64',
#    'votes': 85,
#    'haves': 418,
#    'wants': 1185},
#   {'arttitle': 'John Coltrane With The Red Garland Trio - Traneing In',
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Repress, Mono, Yellow/Black Label',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.67,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 21,
#    'haves': 206,
#    'wants': 204},
#   {'arttitle': 'John Coltrane - My Favorite Things',
#    'rlabel': 'Atlantic',
#    'rformat': 'Vinyl, LP, Album, Mono, Laminated Cover, Scranton Press',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Modal',
#    'rating': 4.0,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 1,
#    'haves': 13,
#    'wants': 89},
#   {'arttitle': 'Ike Quebec - It Might As Well Be Spring',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1962, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.54,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$500.00',
#    'votes': 13,
#    'haves': 75,
#    'wants': 155},
#   {'arttitle': 'Clifford Brown - Memorial Album',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Compilation, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1956, 7, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Bop, Hard Bop',
#    'rating': 5.0,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$499.00',
#    'votes': 4,
#    'haves': 28,
#    'wants': 77},
#   {'arttitle': 'Benny Golson - Gone With Golson',
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1960, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.7,
#    'media': 'Very Good (VG)',
#    'price': '$500.00',
#    'votes': 10,
#    'haves': 66,
#    'wants': 165},
#   {'arttitle': 'Booker Ervin With Dexter Gordon - Setting The Pace',
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1967, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 3.82,
#    'media': 'Mint (M)',
#    'price': '$500.00',
#    'votes': 11,
#    'haves': 114,
#    'wants': 90},
#   {'arttitle': 'Wes Montgomery - The Incredible Jazz Guitar Of Wes Montgomery',
#    'rlabel': 'Riverside Records',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1960, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.53,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 40,
#    'haves': 260,
#    'wants': 597},
#   {'arttitle': "Hank Mobley Quintet* - Mobley's 2nd Message",
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1957, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.5,
#    'media': 'Very Good (VG)',
#    'price': '$500.00',
#    'votes': 8,
#    'haves': 53,
#    'wants': 165},
#   {'arttitle': "Bennie Green - Walkin' And Talkin'",
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.69,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$500.00',
#    'votes': 13,
#    'haves': 86,
#    'wants': 189},
#   {'arttitle': "Cannonball Adderley - Somethin' Else",
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono, Deep Groove',
#    'country': 'US',
#    'release_dt': datetime.datetime(1960, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Bop, Hard Bop',
#    'rating': 4.79,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$475.24',
#    'votes': 19,
#    'haves': 127,
#    'wants': 369},
#   {'arttitle': 'Jackie McLean - Destination... Out!',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1964, 10, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Post Bop',
#    'rating': 4.53,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 43,
#    'haves': 176,
#    'wants': 493},
#   {'arttitle': 'Art Blakey & The Jazz Messengers - A Night In Tunisia',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 3, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.62,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$500.00',
#    'votes': 21,
#    'haves': 134,
#    'wants': 339},
#   {'arttitle': 'Horace Silver Quintet* - Horace Silver Quintet Volume 3',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, 10", Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1954, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.5,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$450.00',
#    'votes': 4,
#    'haves': 35,
#    'wants': 123},
#   {'arttitle': "Jackie McLean - Makin' The Changes",
#    'rlabel': 'New Jazz',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1960, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.6,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 15,
#    'haves': 90,
#    'wants': 181},
#   {'arttitle': 'Jackie McLean - Let Freedom Ring',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Mono, No DG',
#    'country': 'US',
#    'release_dt': datetime.datetime(1963, 4, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.56,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$500.00',
#    'votes': 18,
#    'haves': 98,
#    'wants': 250},
#   {'arttitle': 'Wayne Shorter - Juju',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1964, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.68,
#    'media': 'Very Good (VG)',
#    'price': '$500.00',
#    'votes': 31,
#    'haves': 136,
#    'wants': 706},
#   {'arttitle': 'Woods* / Byrd* - The Young Bloods',
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1956, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.6,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 10,
#    'haves': 50,
#    'wants': 177},
#   {'arttitle': 'The Jazz Messengers* - At The Cafe Bohemia Volume 2',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1956, 5, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.62,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$449.80',
#    'votes': 29,
#    'haves': 205,
#    'wants': 409},
#   {'arttitle': 'Dizzy Reece - Star Bright',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.71,
#    'media': 'Very Good (VG)',
#    'price': '$500.00',
#    'votes': 14,
#    'haves': 92,
#    'wants': 255},
#   {'arttitle': 'Horace Parlan Quintet - On The Spur Of The Moment',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.5,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$500.00',
#    'votes': 8,
#    'haves': 76,
#    'wants': 194},
#   {'arttitle': 'Ike Quebec - Heavy Soul',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1962, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.77,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$450.00',
#    'votes': 26,
#    'haves': 142,
#    'wants': 252},
#   {'arttitle': 'John Coltrane - Blue Train',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Repress, Mono, ®',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.75,
#    'media': 'Very Good (VG)',
#    'price': '$437.39',
#    'votes': 69,
#    'haves': 312,
#    'wants': 986},
#   {'arttitle': 'Thad Jones, Billy Mitchell, Al Grey, Tommy Flanagan, Paul Chambers (3), Elvin Jones - Motor City Scene',
#    'rlabel': 'United Artists Records',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 3.5,
#    'media': 'Very Good (VG)',
#    'price': '$499.99',
#    'votes': 2,
#    'haves': 20,
#    'wants': 115},
#   {'arttitle': 'Hal Stein & Warren Fitzgerald (2) - Hal Stein & Warren Fitzgerald',
#    'rlabel': 'Progressive Records (2)',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1955, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Bop',
#    'rating': 3.5,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$499.99',
#    'votes': 4,
#    'haves': 15,
#    'wants': 34},
#   {'arttitle': 'Hank Mobley - No Room For Squares',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1964, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.68,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$499.99',
#    'votes': 34,
#    'haves': 239,
#    'wants': 630},
#   {'arttitle': "Jackie McLean - Jackie's Bag",
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1967, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 5.0,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$499.00',
#    'votes': 1,
#    'haves': 5,
#    'wants': 80},
#   {'arttitle': 'Hank Mobley - The Turnaround',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono, Plastylite Pressing',
#    'country': 'US',
#    'release_dt': datetime.datetime(1965, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.66,
#    'media': 'Very Good (VG)',
#    'price': '$499.00',
#    'votes': 35,
#    'haves': 196,
#    'wants': 373},
#   {'arttitle': 'Tommy Flanagan, John Coltrane, Kenny Burrell, Idrees Sulieman - The Cats',
#    'rlabel': 'New Jazz',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.43,
#    'media': 'Very Good (VG)',
#    'price': '$425.00',
#    'votes': 21,
#    'haves': 121,
#    'wants': 487},
#   {'arttitle': 'Sonny Rollins - Plus 4',
#    'rlabel': 'Esquire',
#    'rformat': 'Vinyl, LP, Album',
#    'country': 'UK',
#    'release_dt': datetime.datetime(1957, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.5,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$490.00',
#    'votes': 2,
#    'haves': 26,
#    'wants': 111},
#   {'arttitle': 'Miles Davis Sextet* - Someday My Prince Will Come',
#    'rlabel': 'Columbia',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.42,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$475.00',
#    'votes': 57,
#    'haves': 652,
#    'wants': 268},
#   {'arttitle': 'Tubby Hayes And The Jazz Couriers Featuring Ronnie Scott - The Jazz Couriers',
#    'rlabel': 'Tempo Records (5)',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'UK',
#    'release_dt': datetime.datetime(1958, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.33,
#    'media': 'Very Good (VG)',
#    'price': '$468.00',
#    'votes': 6,
#    'haves': 25,
#    'wants': 136},
#   {'arttitle': 'Hank Mobley - Workout',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.53,
#    'media': 'Very Good (VG)',
#    'price': '$455.00',
#    'votes': 19,
#    'haves': 111,
#    'wants': 505},
#   {'arttitle': 'Michael Naura Quintet* - European Jazz Sounds',
#    'rlabel': 'Brunswick',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'Germany',
#    'release_dt': datetime.datetime(1963, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Modal',
#    'rating': 4.7,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$450.00',
#    'votes': 10,
#    'haves': 26,
#    'wants': 188},
#   {'arttitle': 'Yusef Lateef And His Jazz Quintet* - The Fabric Of Jazz',
#    'rlabel': 'Savoy Records',
#    'rformat': 'Vinyl, LP, Album, Stereo',
#    'country': 'US',
#    'release_dt': datetime.datetime(1959, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop, Modal',
#    'rating': 5.0,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$450.00',
#    'votes': 3,
#    'haves': 23,
#    'wants': 116},
#   {'arttitle': 'Art Blakey Quintet - A Night At Birdland, Volume 1',
#    'rlabel': 'Blue Note',
#    'rformat': 'Vinyl, LP, Compilation, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1956, 7, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.6,
#    'media': 'Very Good Plus (VG+)',
#    'price': '$450.00',
#    'votes': 20,
#    'haves': 149,
#    'wants': 365},
#   {'arttitle': "The Miles Davis Quintet - Steamin' With The Miles Davis Quintet",
#    'rlabel': 'Prestige',
#    'rformat': 'Vinyl, LP, Album, Mono',
#    'country': 'US',
#    'release_dt': datetime.datetime(1961, 1, 15, 0, 0),
#    'genre': 'Jazz',
#    'style': 'Hard Bop',
#    'rating': 4.57,
#    'media': 'Near Mint (NM or M-)',
#    'price': '$450.00',
#    'votes': 83,
#    'haves': 836,
#    'wants': 645},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan},
#   {'arttitle': 'Discogs - Error 429',
#    'rlabel': '',
#    'rformat': '',
#    'country': '',
#    'release_dt': '',
#    'genre': '',
#    'style': '',
#    'rating': nan,
#    'media': '',
#    'price': nan,
#    'votes': nan,
#    'haves': nan,
#    'wants': nan}]]

# %% [markdown]
# ### Convert both of these dictionaries to DF and MERGE

# %%
print(len(inneralbinfo[0]))

# %% [markdown]
# ### Function: Pull data from each row in album list

# %%
def pullalb():
    albumlist = {}

    for row in rows[0:]:

        '''
        items are the number of items within a td block (columns).
        there are 6 items in a block
        '''
        items = row.find_all('td')
        #print(len(items))
        #print(items)

        #link = row.find('a')['href']    
        # just take the first item in the td block whihch is link
        link = items[1].find('a')['href']
        #print(link)

        # for title, take the full artist+title for uniqueness. otherwise, dictionary will get unique artist only
        _link = items[1].find('a')

        #arttitle= _link.text #.split('-')[0].strip()

        artist= _link.text.split('-')[0].strip()

        #title1 = title_string.split('-')[1].strip()

        title1 = _link.text.split('-')[1].strip()
        title  = title1.split('(')[0].strip()

        arttitle=artist+" - "+title
        #print("art+title",arttitle,"art",artist)

        # sleeve
        if items[1].find('span',class_="item_sleeve_condition"):
            sleeve=items[1].find('span',class_="item_sleeve_condition").text.strip()
            #print(sleeve)
        else:
            sleeve=''
        
        albumlist[arttitle] = [link] + [artist] + [title] + [sleeve]
        #print(albumlist)
        #albumlist[title] = [link] + [i.text for i in items]

    albumlist

# %% [markdown]
# ### Scraping Multiple Pages
#
# Now that we have the links for album lists we can visit each link to extract even more information about each record.

# %% [markdown]
# ### Create DF of dictionary above and Transpose

# %%
# you put into the function so remove
# alb = pd.DataFrame(albumlist).T
# alb.columns
# alb.columns = ['link_stub','artist','title','sleeve']
# alb

# %% [markdown]
# ### Function: Use full list of records to scrape individual record info

# %%
def get_album_dict(link):
    '''
    From discogs link stub, request html, parse with BeautifulSoup, and
    collect 
        - artist + title        
        - label
        - format
        - country
        - released
        - genre
        - style
        - haves
        - wants
        - avg rating
        - rates        
        - price
        - media
        - sleeve
        
    Return information as a dictionary.
    '''
    
    base_url = 'https://www.discogs.com'
    
    
    #Create full url to scrape
    url = base_url + link
    #print(url)
    
    ua = UserAgent()
    user_agent = {'User-agent': ua.random}
    #response  = requests.get(url, headers = user_agent)    
    
    #Request HTML and parse
    response = requests.get(url,headers=user_agent)
    page = response.text
    soup = BeautifulSoup(page,"lxml")

    
    headers = ['arttitle',
               'rlabel',
               'rformat',
               'country',
               'release_dt',
               'genre',
               'style',
               'rating',
               'media',
               #'sleeve', 
               'price',
               'votes',
               'haves',
               'wants'
              ]
    
    #Get title
    title_string = soup.find('title').text    
    artist = title_string.split('-')[0].strip()    
    title1 = title_string.split('-')[1].strip()
    title  = title1.split(':')[0].strip()
    
    arttitle = artist+" - "+title
#     arttitle= _link.text #.split('-')[0].strip()
#     artist= _link.text.split('-')[0].strip()
#     title = _link.text.split('-')[1].strip()
    

    #Get label (unicode split - need to figure out how to split)
    #rlabel = get_album_txt(soup,'Label:').split(r'-')[0].strip()
    
    if get_album_txt(soup,'Label:'):
        rlabel = get_album_txt(soup,'Label:').split('\u200e')[0].strip()
    else:
        rlabel=''
    
    #Get format
    if get_album_txt(soup,'Format:'):
        rformat = get_album_txt(soup,'Format:').strip()
    else:
        rformat=''
    #print(rformat)
    
    #Get country    
    if get_album_txt(soup,'Country:'):        
        country = get_album_txt(soup,'Country:').strip()
    else:
        country=''
    #print(country)
    
    #Get release date
    if get_album_txt(soup,'Released:'):
        release_dt = get_album_txt(soup,'Released:').strip()
        release_dt = to_date(release_dt)
    else:
        release_dt =''
    #print(release_dt)
    
    #Get genre
    if get_album_txt(soup,'Genre:'):
        genre = get_album_txt(soup,'Genre:').strip()
    else:
        genre=''
    #print(genre)
    
    #Get style
    if get_album_txt(soup,'Style:'):
        style = get_album_txt(soup,'Style:').strip()
    else:
        style=''
    #print(style)
    
    #Get rating    
    _rating = get_album_txt(soup,'Rated')
    if _rating:
        rating= float(_rating)
    else:
        rating=float('NaN')
    
    #Media
    if get_album_txt(soup,'Media:'):
        media = get_album_txt(soup,'Media:').strip()
    else:
        media=''
    #print(media)
    
    #Sleeve (use 'condition' for sleeve condition)
#     sleeve = get_album_sleeve(soup,'Condition').strip()
#     print(sleeve)
    
    #Price (remove $)
    #if get_album_price(soup,'price'):
    price = get_album_price(soup,'price')
    #price = money_to_int(_price)
    #else:
    #    price = float('Nan')
    #print(price)
    
    # votes 
    if get_album_votes(soup,'votes','vote'):
        _votes= get_album_votes(soup,'votes','vote')    
        votes=int(float(_votes))
    else:
        votes=float('NaN')

    # haves
    if get_album_votes(soup,'votes','have'):
        _haves= get_album_votes(soup,'votes','have')    
        haves=int(float(_haves))
    else:
        haves=float('NaN')
        
    # wants
    if get_album_votes(soup,'votes','want'):
        _wants= get_album_votes(soup,'votes','want')    
        wants=int(float(_wants))
    else:
        wants=float('NaN')
    
    #Create album dictionary and return
    album_dict = dict(zip(headers, [arttitle,
                                    rlabel,
                                    rformat,
                                    country,
                                    release_dt,
                                    genre,
                                    style ,
                                    rating, 
                                    media,
                                    #sleeve,
                                    price,
                                    votes,
                                    haves,
                                    wants
                                   ]))
    return album_dict

    time.sleep(2+2*random.random())

# %% [markdown]
# #### Call the function to pull data

# %%
# LINK_STUB is the added parts to the URL
alb_page_info_list = []

for link in alb.link_stub:
    alb_page_info_list.append(get_album_dict(link))

# %% [markdown]
# ## For Loop to pull data

# %%
import random
import time


# 1. get list of 100 items into row and create df

# append the page number
page_list = ['1','2']

for page in page_list:
    
    url= "https://www.discogs.com/sell/list?sort=listed%2Casc&currency=USD&limit=25&page=" + str(page) + "#more%3Dyear"
    response=requests.get(url)
    page = response.text
    soup = BeautifulSoup(page, "lxml")
    #print(page)
    
    time.sleep(.5+2*random.random())

# %% [markdown]
# ### This is your dictionary of x albums for data

# %%
alb_page_info_list

# %% [markdown]
# ### III. bringing together data

# %%
alb_page_info = pd.DataFrame(alb_page_info_list)  #convert list of dict to df
alb_page_info.set_index('arttitle', inplace=True)

alb_page_info

# %% [markdown]
# (Note: the rating is indeed missing from a few of these pages!  How could you fix that?)
#
# We can now match this back up with the movie information collected from the table by merging these dataframes.

# %%
alb_page_info.columns

# %%
alb.shape

# %% [markdown]
# ### Merge DF together

# %%
alb_mrg = alb.merge(alb_page_info, left_index=True, right_index=True)

alb_mrg

# %%
alb_mrg.to_csv('discog2.csv')

# %% [markdown]
# ## TESTING

# %% [markdown]
# ### List page
# - this page gives a list of 250 records based on teh filter criteria used
# - this is only used for testing on code below

# %%
#url='https://www.discogs.com/La-Monte-Young-Drift-Study-43740-50950-PM-5-VIII-68-NYC/release/1512276'
url='https://www.discogs.com/sell/list?sort=price%2Cdesc&limit=250&year1=1900&year2=1970&format=Vinyl&price=over40&genre=Jazz&currency=USD'
response=requests.get(url)
response.status_code

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "lxml")

# %%
print(soup.prettify()) ## Makes the code nice

# %% [markdown]
# #### .find gives you FIRST instance of tag

# %%
soup.find('a')

# %% [markdown]
# #### .find_all gives ALL instances. you can select instance

# %%
soup.find_all('a')[-1]

# %% [markdown]
# #### Extracting things like HREF from an element in HTML

# %%
testing = soup.find_all('a')[-1]

# %%
testing.get("href")

# %% [markdown]
# ### Test on individual record
# - this gives an idea of each record that is clicked and the info in it

# %%
url='https://www.discogs.com/sell/item/1105531603'
response=requests.get(url)
response.status_code

# %%
_page = response.text

# %%
_soup = BeautifulSoup(_page, "lxml")

# %%
#sleeve=_soup.find(text=re.compile('Condition'))
#next_element = sleeve.findNext()

#sleeve = get_album_txt(_soup,'Sleeve:').strip()

#x=next_element.find_all('p')[1].text

#y=x.findNext()
#print(sleeve)
#print(next_element,x)
#print(x,y)
#print(x)

#y=x.split(' ',0)[0].split(':',1)[1].strip()


#print(y)
#_soup.find(class_='section_content').find_all('strong').text

# haves= splithaves.split(',',1)[0].split(' ',1)[0]
# print(haves)

_sleeve=_soup.find(text=re.compile('Condition'))
#_sleeve=_soup.find(class_='section_content')
#print(_sleeve)

#sleeve2=_sleeve.find_all(text=re.compile('Media:'))
#print('sleeve2',sleeve2)

_sleeve2=_sleeve.findNext(text=re.compile('Sleeve'))
print(_sleeve2)

x=_sleeve2.find_all('a')
print(x)

#_sleeve2=_sleeve.findNext().find('a')[1].text
#print(_sleeve2)

#_sleeve3=_sleeve2.find_all('p')[1].text

sleeve=_sleeve2.split(' ',0)[0].split(':',1)[1].strip()
#print(sleeve)

# %% [markdown]
# #### Based on function for album price

# %%
# string of have/wants, etc. they need to be parsed
price = get_album_price(soup,'price')
print(price)

# %%
#Get domestic gross
def get_album_txt2(soup, field_name):
    r = (soup.find_all(class_=field_name)[0]).text
    return r
get_album_txt2(soup,'price')

# %%
# string of have/wants, etc. they need to be parsed
# potentially separate way to get ratings 
rateetc = get_album_price(soup,'rating_value_sm')
print(rateetc)

# %%
rs = soup.find(text=re.compile('Rated'))
next_element = rs
next_element2 = next_element.findNext()    
print(next_element2)

# %% [markdown]
# #### Votes gives us the info we need for votes and haves/wants

# %%
print(soup.find(text=re.compile('votes')))

# %%
# country
country = get_album_txt(soup,'Country:').strip()
print(country)

# %%
# media condition
media = get_album_txt(soup,'Media:').strip()
print(media)

# %%
sleeve = get_album_txt(soup,'Sleeve:').strip()
print(sleeve)

# %%
# media condition
rlabel = get_album_txt(soup,'Label:').strip()
print(rlabel)

# %%
# votes, haves, wants
votes = get_album_txt(soup,'votes').strip()
print(votes)

# %% [markdown]
# ### Testing : get votes, haves wants
# - this one works but refined futher below

# %%
# def get_album_votes(soup, field_name):
    
#     '''Grab a value from discogs archive HTML
#        Takes info in votes containing #votes, haves, wants
#     '''    
#     obj = soup.find(text=re.compile(field_name))
#     return obj
#     if not obj: 
#         return None

# %%
# string of have/wants, etc. they need to be parsed
votestr = get_album_votes(_soup,'votes')
print(votestr)

# %% [markdown]
# #### Testing of parsing individually

# %%
splitvotes = votestr.split('(')[0].strip()
print(splitvotes)

# parse votes
votes = splitvotes.split(' ',1)[1].split(' ',1)[0]
print(votes)

# parse haves
splithaves = votestr.split('(')[1].strip()
print(splithaves)

haves= splithaves.split(',',1)[0].split(' ',1)[0]
print(haves)

# parse wants
splitwants = votestr.split('(')[1].split(',',1)[1].strip()
wants = splitwants.split(' ',1)[0]
print(wants)

# %% [markdown]
# #### Testing to get artist, title

# %%
#Get title
title_string = soup.find('title').text
artist = title_string.split('-')[0].strip()
title1 = title_string.split('-')[1].strip()
title2 = title1.split(':')[0].strip()
print(artist,title2)

# %% [markdown]
# ### LECTURES:
# - linear regression
# - cross validation<br>
#     . 80% training<br>
#     . 20% testing<br>
# - categorical (one hot encoding)
# - continuous - standardize (z scores?)

# %% [markdown]
# #### testing how this function works

# %% [markdown]
# looping through append put replace
# tutorilal - section
# webmojo - base url - indiv
# made list of extra part of link appended
#
# tutorial scrape
# .
#
# for loop for indiidual pages
# list of ind link stub
# . for loop -f
